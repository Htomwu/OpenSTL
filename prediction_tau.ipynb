# %%
import numpy as np
from openstl.utils import show_video_line

# show the given frames from an example
inputs = np.load('./work_dirs/SPEI-3-TAU/saved/inputs.npy')
preds = np.load('./work_dirs/SPEI-3-TAU/saved/preds.npy')
trues = np.load('./work_dirs/SPEI-3-TAU/saved/trues.npy')

example_idx = 0
show_video_line(trues[example_idx], ncols=1, vmax=0.6, cbar=False, out_path=None, format='png', use_rgb=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from openstl.utils import show_video_line
#       4 # show the given frames from an example
#       5 inputs = np.load('./work_dirs/SPEI-3-TAU/saved/inputs.npy')
#
# File ~/Desktop/OpenSTL/openstl/utils/__init__.py:4
#       1 # Copyright (c) CAIRI AI Lab. All rights reserved
#       3 from .config_utils import Config
# ----> 4 from .main_utils import (print_log, output_namespace, collect_env, check_dir,
#       5                         get_dataset, measure_throughput, load_config, update_config, get_dist_info)
#       6 from .parser import create_parser, default_parser
#       7 from .predrnn_utils import (reserve_schedule_sampling_exp, schedule_sampling, reshape_patch,
#       8                         reshape_patch_back)
#
# ...
